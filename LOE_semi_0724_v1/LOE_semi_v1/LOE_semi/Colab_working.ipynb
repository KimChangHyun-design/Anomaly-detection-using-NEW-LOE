# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.chdir("/content/drive/MyDrive/LOE_semi")

# %%
# !python Launch_Exps.py --simu_num 1 --config-file config_simulation_ntl_plus_soft.yml --dataset-name simulation_data_ntl_plus --contamination 0.1 --anomaly_rate 0.3 --model_configuration.train_method loe_hard_semi
# Out:
# Normal Cls: 0
# Epoch: 1, TR loss: 0.9156405639648437, VAL loss: (0.8686175537109375, 0.9185627746582031), VL auc: 0.9334777777777777 VL ap: 0.6060623647838338 VL f1: 0.66
# Epoch: 2, TR loss: 0.8448364868164062, VAL loss: (0.7687661404079861, 0.8699456024169921), VL auc: 0.9409555555555555 VL ap: 0.7469298590416731 VL f1: 0.72
# Epoch: 4, TR loss: 0.59202734375, VAL loss: (0.6224231635199653, 0.7462405395507813), VL auc: 0.9089333333333334 VL ap: 0.5328860066516564 VL f1: 0.57
# Epoch: 6, TR loss: 0.47979510498046873, VAL loss: (0.5097242228190104, 0.7389039611816406), VL auc: 0.9485222222222223 VL ap: 0.799626895619754 VL f1: 0.74
# Epoch: 8, TR loss: 0.3948011779785156, VAL loss: (0.42038519965277776, 0.709317855834961), VL auc: 0.946211111111111 VL ap: 0.8213778541183077 VL f1: 0.78
# Epoch: 10, TR loss: 0.3393620300292969, VAL loss: (0.3693680148654514, 0.6920489501953125), VL auc: 0.9496444444444444 VL ap: 0.8330075286924299 VL f1: 0.8000000000000002
# ...
